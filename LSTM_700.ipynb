# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import numpy as np
from keras.datasets import imdb

# %%
# Define data
# set the maximum number of words to use
max_num_words = 10000

# set the maximum length of each sequence
max_sequence_length = 700

# load the IMDB dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_num_words)

# pad the sequences to a fixed length
x_train = pad_sequences(x_train, maxlen=max_sequence_length)
x_test = pad_sequences(x_test, maxlen=max_sequence_length)

# print the shapes of the data
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# x_train shape: (25000, 700)
# y_train shape: (25000,)
# x_test shape: (25000, 700)
# y_test shape: (25000,)

# %%
# Define input shape
input_shape = (700,)

# Define input layer
inputs = Input(shape=input_shape)

# Define embedding layer
embedding_size = 128
vocab_size = 10000
embeddings = Embedding(input_dim=vocab_size, output_dim=embedding_size)(inputs)

# Define LSTM layer
lstm_units = 64
lstm_out = LSTM(units=lstm_units)(embeddings)

# Define output layer
outputs = Dense(1, activation='sigmoid')(lstm_out)

# Define model
model = Model(inputs=inputs, outputs=outputs)

# %%
# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# print the model summary
model.summary()

# train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate model
loss, accuracy = model.evaluate(x_test, y_test, batch_size=1)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 700)]             0
#
#  embedding (Embedding)       (None, 700, 128)          1280000
#
#  lstm (LSTM)                 (None, 64)                49408
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 1,329,473
# Trainable params: 1,329,473
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 625/625 [==============================] - 109s 162ms/step - loss: 0.4284 - accuracy: 0.8024 - val_loss: 0.3443 - val_accuracy: 0.8568
# Epoch 2/10
# 625/625 [==============================] - 46s 74ms/step - loss: 0.2540 - accuracy: 0.9008 - val_loss: 0.3969 - val_accuracy: 0.8506
# Epoch 3/10
# 625/625 [==============================] - 30s 48ms/step - loss: 0.1861 - accuracy: 0.9302 - val_loss: 0.3395 - val_accuracy: 0.8570
# Epoch 4/10
# 625/625 [==============================] - 26s 41ms/step - loss: 0.1437 - accuracy: 0.9467 - val_loss: 0.3815 - val_accuracy: 0.8616
# Epoch 5/10
# 625/625 [==============================] - 24s 38ms/step - loss: 0.0891 - accuracy: 0.9692 - val_loss: 0.4445 - val_accuracy: 0.8592
# Epoch 6/10
# 625/625 [==============================] - 19s 31ms/step - loss: 0.2004 - accuracy: 0.9112 - val_loss: 0.4504 - val_accuracy: 0.8020
# Epoch 7/10
# 625/625 [==============================] - 17s 27ms/step - loss: 0.1372 - accuracy: 0.9482 - val_loss: 0.4252 - val_accuracy: 0.8740
# Epoch 8/10
# 625/625 [==============================] - 19s 31ms/step - loss: 0.0582 - accuracy: 0.9799 - val_loss: 0.4538 - val_accuracy: 0.8720
# Epoch 9/10
# 625/625 [==============================] - 19s 30ms/step - loss: 0.0415 - accuracy: 0.9862 - val_loss: 0.5272 - val_accuracy: 0.8728
# Epoch 10/10
# 625/625 [==============================] - 18s 29ms/step - loss: 0.0209 - accuracy: 0.9939 - val_loss: 0.6441 - val_accuracy: 0.8574
# 25000/25000 [==============================] - 218s 9ms/step - loss: 0.7069 - accuracy: 0.8452
# Test loss: 0.7069361209869385, Test accuracy: 0.8452399969100952
